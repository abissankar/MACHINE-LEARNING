# %%
import pandas as pd
import numpy as np

# %%
a=np.array([1,2,3,4,5])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a[1]
# Out:
# 2

# %%
s=pd.Series([1,2,4,5,6])

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    1
# 1    2
# 2    4
# 3    5
# 4    6
# dtype: int64

# %%
s[1]
# Out:
# 2

# %%
s.drop([1]) #removes the particular row
# Out:
# 0    1
# 2    4
# 3    5
# 4    6
# dtype: int64

# %%
s.drop(3,inplace=True)
s
# Out:
# 0    1
# 1    2
# 2    4
# 4    6
# dtype: int64

# %%
s[1]
# Out:
# 2

# %%
s[3]# error because deleted using inplace
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
s.iloc[1] #next number replaces the removed element #selection by index
# Out:
# 2

# %%
s.loc[4]# selection by labels
# Out:
# 6

# %%
s.index
# Out:
# Int64Index([0, 1, 2, 4], dtype='int64')

# %%
ss=pd.Series([1,2,3,5,6],index=['a','b','c','d','e']) #to change the index name
ss
# Out:
# a    1
# b    2
# c    3
# d    5
# e    6
# dtype: int64

# %%
ss=pd.Series([1,2,3,5,6],index=['a','a','c','d','e']) #to change the index name
ss
# Out:
# a    1
# a    2
# c    3
# d    5
# e    6
# dtype: int64

# %%
ss.loc['a']# lab val
# Out:
# a    1
# a    2
# dtype: int64

# %%
ss.iloc[1]#index val
# Out:
# 2

# %%
dt=[['a',10,'28.08.2003'],['b',56,'23.3.4'],['C',None,'20.12.2003']]
dt
# Out:
# [['a', 10, '28.08.2003'], ['b', 56, '23.3.4'], ['C', None, '20.12.2003']]

# %%
df=pd.DataFrame(dt)
df
# Out:
#    0     1           2
# 0  a  10.0  28.08.2003
# 1  b  56.0      23.3.4
# 2  C   NaN  20.12.2003

# %%
df=pd.DataFrame(dt,columns=['firstname','age','dob'])
df
# Out:
#   firstname   age         dob
# 0         a  10.0  28.08.2003
# 1         b  56.0      23.3.4
# 2         C   NaN  20.12.2003

# %%
df[0:1]
# Out:
#   firstname   age         dob
# 0         a  10.0  28.08.2003

# %%
df[0:2]
# Out:
#   firstname   age         dob
# 0         a  10.0  28.08.2003
# 1         b  56.0      23.3.4

# %%
df[0:3]
# Out:
#   firstname   age         dob
# 0         a  10.0  28.08.2003
# 1         b  56.0      23.3.4
# 2         C   NaN  20.12.2003

# %%
dt=[['a',10,'28.08.2003'],['b',56,'23.3.4'],['C',None,'20.12.2003']]
df=pd.DataFrame(dt)
df
# Out:
#    0     1           2
# 0  a  10.0  28.08.2003
# 1  b  56.0      23.3.4
# 2  C   NaN  20.12.2003

# %%
df[0][0]
# Out:
# 'a'

# %%
df[[0,2]]
# Out:
#    0           2
# 0  a  28.08.2003
# 1  b      23.3.4
# 2  C  20.12.2003

# %%
s=pd.Series([1,2,3,4,5,6])
s.plot() #plot bw series and index
# Out:
# <Axes: >

# %%
s.hist(bins=1)#x=array,y=array/2     #generate histograms. A histogram is a graphical representation of the distribution of a dataset
# Out:
# <Axes: >

# %%
s.hist(bins=2)
# Out:
# <Axes: >

# %%
s=s.to_numpy()

# %%
type(s)
# Out:
# numpy.ndarray

# %%
df
# Out:
#    0     1           2
# 0  a  10.0  28.08.2003
# 1  b  56.0      23.3.4
# 2  C   NaN  20.12.2003

# %%
df.head() #default first 5
# Out:
#    0     1           2
# 0  a  10.0  28.08.2003
# 1  b  56.0      23.3.4
# 2  C   NaN  20.12.2003

# %%
df.head(1)#
# Out:
#    0     1           2
# 0  a  10.0  28.08.2003

# %%
df.head(2)
# Out:
#    0     1           2
# 0  a  10.0  28.08.2003
# 1  b  56.0      23.3.4

# %%
df.tail(1)
# Out:
#    0   1           2
# 2  C NaN  20.12.2003

# %%
df.tail(2)
# Out:
#    0     1           2
# 1  b  56.0      23.3.4
# 2  C   NaN  20.12.2003

# %%
df.tail(-1)
# Out:
#    0     1           2
# 1  b  56.0      23.3.4
# 2  C   NaN  20.12.2003

# %%
df.tail(-2)
# Out:
#    0   1           2
# 2  C NaN  20.12.2003

# %%
#None,' ','','-',?,Nil,np.nan(not a number)

# %%
df.isnull()
# Out:
#        0      1      2
# 0  False  False  False
# 1  False  False  False
# 2  False   True  False

# %%
df.isnull().sum()
# Out:
# 0    0
# 1    1
# 2    0
# dtype: int64

# %%
dat=[['a',10,'28.08.2003',23],['b',56,'23.3.4',None],['C',None,'20.12.2003',34],['d',45,'24.3.2000',None]]
dat
# Out:
# [['a', 10, '28.08.2003', 23],
#  ['b', 56, '23.3.4', None],
#  ['C', None, '20.12.2003', 34],
#  ['d', 45, '24.3.2000', None]]

# %%
daf=pd.DataFrame(dat)
daf
# Out:
#    0     1           2     3
# 0  a  10.0  28.08.2003  23.0
# 1  b  56.0      23.3.4   NaN
# 2  C   NaN  20.12.2003  34.0
# 3  d  45.0   24.3.2000   NaN

# %%
daf.isnull() #to find nulls
# Out:
#        0      1      2      3
# 0  False  False  False  False
# 1  False  False  False   True
# 2  False   True  False  False
# 3  False  False  False   True

# %%
daf.isnull().sum()
# Out:
# 0    0
# 1    1
# 2    0
# 3    2
# dtype: int64

# %%
daf.dropna() #delete the row with null values
# Out:
#    0     1           2     3
# 0  a  10.0  28.08.2003  23.0

# %%
daf
# Out:
#    0     1           2     3
# 0  a  10.0  28.08.2003  23.0
# 1  b  56.0      23.3.4   NaN
# 2  C   NaN  20.12.2003  34.0
# 3  d  45.0   24.3.2000   NaN

# %%
daf.dropna(inplace=True)
daf
# Out:
#    0     1           2     3
# 0  a  10.0  28.08.2003  23.0

# %%
daf
# Out:
#    0     1           2     3
# 0  a  10.0  28.08.2003  23.0

# %%
dat=[['abi',10,'28.08.2003',23],['bobe',56,'23.3.4',None],['Catte',None,'20.12.2003',34],['dode',45,'24.3.2000',None]]
daf=pd.DataFrame(dat)
daf
# Out:
#        0     1           2     3
# 0    abi  10.0  28.08.2003  23.0
# 1   bobe  56.0      23.3.4   NaN
# 2  Catte   NaN  20.12.2003  34.0
# 3   dode  45.0   24.3.2000   NaN

# %%
daff=pd.DataFrame(dat,columns=['firstname','age','dob','roll'])
daff
# Out:
#   firstname   age         dob  roll
# 0       abi  10.0  28.08.2003  23.0
# 1      bobe  56.0      23.3.4   NaN
# 2     Catte   NaN  20.12.2003  34.0
# 3      dode  45.0   24.3.2000   NaN

# %%
daf.drop([1],axis=1,inplace=True)
daf
# Out:
#        0           2     3
# 0    abi  28.08.2003  23.0
# 1   bobe      23.3.4   NaN
# 2  Catte  20.12.2003  34.0
# 3   dode   24.3.2000   NaN

# %%
daf
# Out:
#        0           2     3
# 0    abi  28.08.2003  23.0
# 1   bobe      23.3.4   NaN
# 2  Catte  20.12.2003  34.0
# 3   dode   24.3.2000   NaN

# %%
daf.drop([0,2])
# Out:
#       0          2   3
# 1  bobe     23.3.4 NaN
# 3  dode  24.3.2000 NaN

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
a>4
# Out:
# array([False, False, False, False,  True])

# %%
a[a>4]
# Out:
# array([5])

# %%
a[a%2!=0]
# Out:
# array([1, 3, 5])

# %%
daf
# Out:
#        0           2     3
# 0    abi  28.08.2003  23.0
# 1   bobe      23.3.4   NaN
# 2  Catte  20.12.2003  34.0
# 3   dode   24.3.2000   NaN

# %%
daf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4 non-null      object
#  1   2       4 non-null      object
#  2   3       2 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 224.0+ bytes

# %%
c=daf[0].str.contains('i')
c
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# Name: 0, dtype: bool

# %%
print(daf.shape)
print(daf.size)
print(daf.axes)
print(daf.ndim)
print(daf.dtypes)
print(daf.index)
print(daf.columns)
print(daf.values)
# Out:
# (4, 4)
# 16
# [RangeIndex(start=0, stop=4, step=1), RangeIndex(start=0, stop=4, step=1)]
# 2
# 0     object
# 1    float64
# 2     object
# 3    float64
# dtype: object
# RangeIndex(start=0, stop=4, step=1)
# RangeIndex(start=0, stop=4, step=1)
# [['abi' 10.0 '28.08.2003' 23.0]
#  ['bobe' 56.0 '23.3.4' nan]
#  ['Catte' nan '20.12.2003' 34.0]
#  ['dode' 45.0 '24.3.2000' nan]]

# %%
df2=pd.concat([daf,daf])
df2
# Out:
#        0     1           2     3
# 0    abi  10.0  28.08.2003  23.0
# 1   bobe  56.0      23.3.4   NaN
# 2  Catte   NaN  20.12.2003  34.0
# 3   dode  45.0   24.3.2000   NaN
# 0    abi  10.0  28.08.2003  23.0
# 1   bobe  56.0      23.3.4   NaN
# 2  Catte   NaN  20.12.2003  34.0
# 3   dode  45.0   24.3.2000   NaN

# %%
daf.describe()
# Out:
#                1          3
# count   3.000000   2.000000
# mean   37.000000  28.500000
# std    24.020824   7.778175
# min    10.000000  23.000000
# 25%    27.500000  25.750000
# 50%    45.000000  28.500000
# 75%    50.500000  31.250000
# max    56.000000  34.000000

# %%
daf.loc[0][0]
# Out:
# 'abi'

# %%
daf[0][1]
# Out:
# 'bobe'

# %%
daf
# Out:
#        0     1           2     3
# 0    abi  10.0  28.08.2003  23.0
# 1   bobe  56.0      23.3.4   NaN
# 2  Catte   NaN  20.12.2003  34.0
# 3   dode  45.0   24.3.2000   NaN

# %%
daf[2][0]='28-08-2003'
daf
# Out:
# <ipython-input-167-9a3d0cc95e67>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daf[2][0]='28-08-2003'
#             0     1           2     3
# 0         abi  10.0  28-08-2003  23.0
# 1  28-08-2003  56.0      23.3.4   NaN
# 2       Catte   NaN  20.12.2003  34.0
# 3        dode  45.0   24.3.2000   NaN
